# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_49.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_67_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_90.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_77.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_20_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_66.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_54.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_106_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_42.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_81.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_72.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_107.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_79.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_83.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_88.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_164.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_116_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_60.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_55.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_25.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_112.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_153_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_132.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_44.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_7.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_119.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_106.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_20.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_59.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_129.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_12.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_31.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_97.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_102_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_40.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_157.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_29.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_37.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_25_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_67.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_132_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_94.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_82.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_61.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_27.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_141.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_100.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_32.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_110.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_19_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_50.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_120.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_113.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_17_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_10_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_56.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_114.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_104.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_71.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_28.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_76.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_96_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_57.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_102.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_149.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_45.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_156_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_41.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_61_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_86.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_79_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_161.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_4.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_162.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_118.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_52_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_19.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_89.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_70.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_87.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_75.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_84.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_95.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_23.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_159.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_137.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_56_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_93.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_142.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_143.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_156.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_14.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_5.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_80.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_13.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_8.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_22.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_85.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_126.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_133_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_38.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_152.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_31_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_47.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_148.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_111.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_127.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_16_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_99_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_130.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_140_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_96.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_98.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_146.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_52.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_16.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_158_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_78.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_101.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_26.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_30.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_158.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_140.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_17.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_154.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_24.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_6.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_92.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_69.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_64.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_131.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_105.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_21.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_35.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_160.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_15.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_63.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_122.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_30_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_125.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_115.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_13_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_68.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_138.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_86_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_155.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_10.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_121.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_48.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_146_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_117.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_11.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_153.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_145.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_39.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_103.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_136.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_46.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_147.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_144.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_135_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_76_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_139.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_161_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_134.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_62.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_18.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_116.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_123.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_133.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_135.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_108.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_109.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_34.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_53.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_150.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_73.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_43.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_99.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_32_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_124.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_9.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_3.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_136_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_65.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_57_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_33.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_58.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_128.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_36.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_74.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_51.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_163.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_91.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test/audio_151.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_49.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_77_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_90.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_77.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_66.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_54.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_237.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_42.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_257.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_256_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_81.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_330.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_72.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_232_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_328.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_107.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_79.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_73_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_83.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_88.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_164.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_283.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_300.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_315.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_60.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_55.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_204.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_25.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_112.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_176.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_256.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_359.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_132.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_44.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_290.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_7.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_234.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_120_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_119.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_321.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_106.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_20.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_59.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_129.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_12.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_40_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_369_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_348.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_166.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_284.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_31.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_97.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_254.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_338.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_40.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_207.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_188.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_233.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_307.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_276.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_289.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_157.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_354.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_29.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_360_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_37.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_67.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_34_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_186.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_253.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_199.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_291.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_289_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_281.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_308.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_94.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_251.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_56_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_232.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_369.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_265.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_82.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_341.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_61.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_27.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_141.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_315_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_371.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_100.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_32.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_274.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_110.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_280.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_231.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_226_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_50.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_115_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_230.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_193.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_327.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_120.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_113.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_295.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_297.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_169.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_154_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_310.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_56.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_346.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_114.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_104.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_189.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_277.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_340.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_190.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_214.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_225.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_347.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_71.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_28.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_76.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_205.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_361.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_345.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_220.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_57.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_102.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_149.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_191.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_45.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_296.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_41.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_275.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_86.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_198.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_138_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_370.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_1_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_328_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_161.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_4.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_223.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_356.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_162.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_165.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_118.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_366.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_210.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_19.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_261.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_10_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_89.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_294.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_70.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_238.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_87.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_322.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_329.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_278.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_298.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_178.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_228.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_314.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_343.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_75.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_217.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_84.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_95.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_170.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_258.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_23.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_159.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_171.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_244.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_175.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_313.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_299.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_351.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_266.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_194.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_137.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_372.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_194_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_93.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_331.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_142.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_177.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_229.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_243.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_143.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_156.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_180.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_26_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_14.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_215.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_309.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_364.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_255.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_319.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_174.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_337.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_5.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_185.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_323.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_238_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_285.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_80.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_13.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_8.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_22.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_355.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_85.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_182.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_126.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_303.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_192.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_38.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_152.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_47.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_218.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_202.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_148.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_111.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_127.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_268.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_130.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_273.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_293.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_96.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_239.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_252.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_311.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_367.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_240.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_326.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_288.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_98.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_235.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_146.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_286.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_263.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_209.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_302.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_181.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_195.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_52.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_16.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_287.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_336_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_365.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_357.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_332.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_181_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_335.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_78.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_224.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_211.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_101.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_339.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_26.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_30.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_216.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_368.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_362.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_158.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_140.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_172.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_219.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_127_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_17.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_154.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_271.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_24.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_317.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_6.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_92.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_69.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_64.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_221.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_131.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_336.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_105.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_21.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_260.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_324.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_35.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_160.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_358.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_318.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_15.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_63.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_249.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_122.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_306_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_222.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_292.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_167.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_125.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_269.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_342.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_334.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_240_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_115.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_245.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_195_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_68.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_138.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_236.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_246.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_200.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_353.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_333.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_155.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_1.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_206.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_264.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_360.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_349.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_10.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_121.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_48.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_279_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_212.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_183.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_168.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_352.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_208.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_316.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_187.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_117.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_242.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_304.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_11.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_282.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_226.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_153.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_363.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_145.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_241.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_109_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_39.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_196.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_173.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_227.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_197.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_213.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_103.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_156_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_136.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_46.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_272.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_312.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_147.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_144.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_350.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_139.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_134.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_62.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_18.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_116.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_123.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_133.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_135.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_203.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_325.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_306.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_108.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_109.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_34.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_279.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_53.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_344.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_250.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_150.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_73.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_43.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_179.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_99.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_184.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_124.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_9.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_3.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_65.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_234_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_102_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_33.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_248.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_58.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_305.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_270.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_301.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_320.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_128.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_247.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_36.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_201.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_74.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_262.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_51.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_16_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_267.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_163.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_64_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_91.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_58_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_43_2.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_151.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train/audio_259.wav
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/csvs/train.csv
# /kaggle/input/shl-intern-hiring-assessment-2025/dataset/csvs/test.csv

# %%
import os
import warnings
from transformers import logging

# 1. Suppress Transformers specific warnings
logging.set_verbosity_error()

# 2. Suppress Python warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Executive Summary
# This project implements an automated AI pipeline to assess the language proficiency of audio recordings. The solution moves beyond simple text transcription by integrating Acoustic Physics (how it was said) with a "Dual-Brain" Embedding System (what was said). This multi-modal approach captures fluency, confidence, and semantic depth, achieving a robust RMSE on the training set.
#
# # 2. Methodology & Reasoning
# ## A. The Challenge
# The core challenge was to predict a grammar score (1-5) from raw audio with a small dataset (~400 samples). A simple "Text-only" approach fails because it ignores stuttering and hesitation. A simple "Audio-only" approach fails because it ignores vocabulary and syntax.
#
# ## B. Feature Engineering Strategy
# We extract a dense 40-dimensional feature vector for each audio file using a three-stage process:
#
# ### Acoustic Physics (Librosa):
#
# We extract 8 fundamental signal metrics including Silence Ratio (fluency), Pitch Stability (confidence), and Speaking Rate. These features help distinguish between a confident speaker and one who is struggling, even if their words are similar.
#
# ### Linguistic Analysis (Whisper + T5):
#
# Audio is transcribed using OpenAI Whisper (Base).
#
# We use a T5 Grammar Correction model to generate a "perfect" version of the transcript. The Levenshtein distance between the user's speech and the T5 correction provides a quantitative "Error Density" score.
#
# ### The "Dual-Brain" Semantic System:
#
# To capture meaning and context without overfitting, we use two distinct Transformer models:
#
# MiniLM-L6 (Brain 1): Fast and efficient, capturing broad keywords and surface-level context.
#
# MPNet-Base (Brain 2): Deep and precise, capturing subtle semantic nuances that smaller models miss.
#
# ## C. Architecture: The "Compress & Ensemble" Approach
# Raw embeddings produce over 1,100 dimensions, which would cause massive overfitting on a dataset of 400 samples. Our solution:
#
# Compression (PCA): We apply Principal Component Analysis to compress each "Brain" down to 16 high-variance components. This retains the linguistic signal while discarding noise.
#
# Hybrid Ensemble: We combine XGBoost (for non-linear patterns) and Ridge Regression (for linear stability).
#
# # 3. Evaluation Results
# Training RMSE: 0.2793
#
# Performance: The model uses a weighted average (60% XGBoost, 40% Ridge). This diversity ensures that the model doesn't memorize the training data but learns generalizable rules of language proficiency.

# %%
# ==========================================
# 0. ENVIRONMENT SETUP
# ==========================================

# 1. Install Python Libraries
# Why? These are not standard in Kaggle kernels but are required for our pipeline.
# - language-tool-python: Checks for grammar rule violations.
# - textstat: Calculates readability indices (Flesch-Kincaid).
# - sentence-transformers: Loads our "Dual-Brain" models (MiniLM, MPNet).
# !pip install -q openai-whisper language-tool-python textstat librosa xgboost sentence-transformers transformers torch Levenshtein scikit-learn

# 2. Install & Configure Java
# Why? The 'language-tool-python' library relies on a Java backend server to run efficiently.
# Kaggle's default environment sometimes has path issues or missing Java runtimes.
# Explicitly installing OpenJDK 17 ensures the grammar checker works without crashing.
import os
print("Configuring Java Environment for Grammar Tool...")
os.system('apt-get update -qq')
os.system('apt-get install -y openjdk-17-jdk-headless -qq > /dev/null')
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

print("Installation Complete.")
# Out:
# Configuring Java Environment for Grammar Tool...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Installation Complete.

# %%
# ==========================================
# 1. SETUP & IMPORTS
# ==========================================
import numpy as np
import pandas as pd
import librosa
import whisper
import language_tool_python
import textstat
from sentence_transformers import SentenceTransformer
from transformers import pipeline
import Levenshtein
import torch
import warnings
import os
import xgboost as xgb
from sklearn.linear_model import Ridge
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# Suppress warnings for cleaner logs
warnings.filterwarnings('ignore')

# Detect Hardware (GPU is crucial for Whisper/Embeddings speed)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Hardware Detected: {DEVICE}")

# ==========================================
# 2. MODEL LOADING
# ==========================================
print("⏳ Loading AI Models...")

# A. Audio Brain (Whisper)
asr_model = whisper.load_model("base", device=DEVICE)

# B. Grammar Tools
grammar_tool = language_tool_python.LanguageTool('en-US')
corrector = pipeline("text2text-generation", model="vennify/t5-base-grammar-correction", device=0 if DEVICE=="cuda" else -1)

# C. The "Dual-Brain" Embedding System
# Brain 1: Fast & Broad Context
model_minilm = SentenceTransformer('all-MiniLM-L6-v2', device=DEVICE)

# Brain 2: Deep Semantic Understanding
model_mpnet = SentenceTransformer('all-mpnet-base-v2', device=DEVICE)

print("All Models Loaded Successfully.")
# Out:
# 2025-12-18 07:54:49.686488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766044489.707289     990 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766044489.713622     990 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Hardware Detected: cuda
# ⏳ Loading AI Models...
# All Models Loaded Successfully.

# %%
# ==========================================
# 3. FEATURE EXTRACTION LOGIC
# ==========================================
def extract_features(audio_path):
    """
    Extracts a multimodal feature vector from an audio file.
    Returns: [8 Scalars] + [MiniLM Embeddings] + [MPNet Embeddings]
    """
    try:
        # --- A. ACOUSTICS ---
        y, sr = librosa.load(audio_path, sr=16000)
        duration = librosa.get_duration(y=y, sr=sr)
        
        # Silence Ratio (Fluency metric)
        intervals = librosa.effects.split(y, top_db=20)
        speech_time = sum(end - start for start, end in intervals) / sr
        silence_ratio = (duration - speech_time) / duration if duration > 0 else 0
        
        # Pitch Stats (Intonation metric)
        f0 = librosa.yin(y, fmin=65, fmax=2093)
        f0 = f0[f0 > 0]
        pitch_std = np.std(f0) if len(f0) > 0 else 0
        
        # --- B. TRANSCRIPTION ---
        result = asr_model.transcribe(y)
        text = result['text'].strip()
        
        # Safety check: if audio is silent/empty, return zero-vector
        # Total dims = 8 scalars + 384 (MiniLM) + 768 (MPNet) = 1160
        if len(text) == 0: return [0] * 1160

        # --- C. GRAMMAR & COMPLEXITY ---
        # 1. "Distance to Perfection" (T5 Comparison)
        corrected_text = corrector("grammar: " + text, max_length=128)[0]['generated_text']
        grammar_similarity = Levenshtein.ratio(text, corrected_text)
        edits = Levenshtein.distance(text, corrected_text)
        edit_density = edits / max(1, len(text.split()))

        # 2. Rule-Based Errors
        matches = grammar_tool.check(text)
        error_density = len(matches) / max(1, len(text.split()))
        
        # 3. Readability Score
        complexity = textstat.flesch_kincaid_grade(text)
        wpm = len(text.split()) / (duration / 60) if duration > 0 else 0
        
        # --- D. DUAL EMBEDDINGS ---
        emb1 = model_minilm.encode(text).tolist()   # 384 dims
        emb2 = model_mpnet.encode(text).tolist()    # 768 dims
        
        # --- E. COMBINE ---
        features = [
            silence_ratio, pitch_std, 
            grammar_similarity, edit_density, 
            error_density, complexity, wpm, len(text.split())
        ]
        features.extend(emb1)
        features.extend(emb2)
        
        return features

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return [0] * 1160

# %%
# ==========================================
# 4. EXECUTION: FEATURE EXTRACTION (TRAIN)
# ==========================================
print("\n--- Phase 1: Feature Extraction (Train) ---")
# Import tqdm for progress bars
from tqdm.auto import tqdm

# Adjust paths for Kaggle environment
TRAIN_CSV = '/kaggle/input/shl-intern-hiring-assessment-2025/dataset/csvs/train.csv'
AUDIO_DIR_TRAIN = '/kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/train'

df_train = pd.read_csv(TRAIN_CSV)
X_train = []
y_train = []

# Wrap the loop with tqdm() to show a progress bar
print("Extracting features...")
for index, row in tqdm(df_train.iterrows(), total=len(df_train), desc="Processing Train"):
    filename = row['filename']
    label = row['label']
    
    if not filename.endswith('.wav'): 
        filename += '.wav'
    
    file_path = os.path.join(AUDIO_DIR_TRAIN, filename)
    
    X_train.append(extract_features(file_path))
    y_train.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)

# ==========================================
# 5. PREPROCESSING & PCA
# ==========================================
print("\n--- Phase 2: Preprocessing & PCA ---")

X_df = pd.DataFrame(X_train)
y = np.array(y_train)

# Indices for splitting the massive vector
scalar_cols = list(range(8))
emb1_cols = list(range(8, 392))       # MiniLM
emb2_cols = list(range(392, 1160))    # MPNet

# 1. Scale Scalars
scaler = StandardScaler()
X_scalars = scaler.fit_transform(X_df.iloc[:, scalar_cols].values)

# 2. Compress Embeddings (PCA)
# We compress each "Brain" separately to 16 dimensions to prevent overfitting
print("Fitting PCA on Embeddings...")
pca1 = PCA(n_components=16, random_state=42)
X_emb1 = pca1.fit_transform(X_df.iloc[:, emb1_cols].values)

pca2 = PCA(n_components=16, random_state=42)
X_emb2 = pca2.fit_transform(X_df.iloc[:, emb2_cols].values)

# 3. Combine: 8 + 16 + 16 = 40 Features
X_final_train = np.hstack([X_scalars, X_emb1, X_emb2])
print(f"Final Feature Matrix Shape: {X_final_train.shape}")

# ==========================================
# 6. MODEL TRAINING & RMSE CALCULATION
# ==========================================
print("\n--- Phase 3: Training Ensemble ---")

# Model 1: XGBoost (Pattern Recognition)
model_xgb = xgb.XGBRegressor(
    n_estimators=600, learning_rate=0.015, max_depth=5,
    min_child_weight=1, subsample=0.7, colsample_bytree=0.7, 
    n_jobs=-1, random_state=42
)
model_xgb.fit(X_final_train, y)

# Model 2: Ridge (Linear Stability)
model_ridge = Ridge(alpha=1.0)
model_ridge.fit(X_final_train, y)

print("Models Trained.")

# --- COMPULSORY: CALCULATE TRAINING RMSE ---
print("Calculating Training RMSE...")
p1_train = model_xgb.predict(X_final_train)
p2_train = model_ridge.predict(X_final_train)

# Ensemble Weights: 60% XGB, 40% Ridge
train_final_preds = (p1_train * 0.6) + (p2_train * 0.4)

rmse = np.sqrt(mean_squared_error(y, train_final_preds))
print(f"FINAL TRAINING RMSE SCORE: {rmse:.4f}")
# Out:
# --- Phase 1: Feature Extraction (Train) ---
# Extracting features...
# Processing Train:   0%|          | 0/409 [00:00<?, ?it/s]
# --- Phase 2: Preprocessing & PCA ---
# Fitting PCA on Embeddings...
# Final Feature Matrix Shape: (409, 40)
#
# --- Phase 3: Training Ensemble ---
# Models Trained.
# Calculating Training RMSE...
# FINAL TRAINING RMSE SCORE: 0.2793

# %%
# ==========================================
# 7. TESTING & SUBMISSION
# ==========================================
print("\n--- Phase 4: Feature Extraction (Test) ---")
from tqdm.auto import tqdm

TEST_CSV = '/kaggle/input/shl-intern-hiring-assessment-2025/dataset/csvs/test.csv'
AUDIO_DIR_TEST = '/kaggle/input/shl-intern-hiring-assessment-2025/dataset/audios/test'

df_test = pd.read_csv(TEST_CSV)
X_test_raw = []

# --- EXTRACT FEATURES (With Progress Bar) ---
print("Extracting features from Test Data...")
for index, row in tqdm(df_test.iterrows(), total=len(df_test), desc="Processing Test"):
    filename = row['filename']
    if not filename.endswith('.wav'): filename += '.wav'
    file_path = os.path.join(AUDIO_DIR_TEST, filename)
    
    X_test_raw.append(extract_features(file_path))

X_test_df = pd.DataFrame(np.array(X_test_raw))

# --- APPLY TRANSFORMS ---
print("Applying Transforms to Test Data...")
# Use the Scaler/PCAs fitted on Training Data
X_test_scalars = scaler.transform(X_test_df.iloc[:, scalar_cols].values)
X_test_emb1 = pca1.transform(X_test_df.iloc[:, emb1_cols].values)
X_test_emb2 = pca2.transform(X_test_df.iloc[:, emb2_cols].values)

X_final_test = np.hstack([X_test_scalars, X_test_emb1, X_test_emb2])

# --- FINAL PREDICTION ---
print("Generating Submission...")
p1 = model_xgb.predict(X_final_test)
p2 = model_ridge.predict(X_final_test)

# Ensemble Weights: 60% XGB, 40% Ridge
final_preds = (p1 * 0.6) + (p2 * 0.4)

# Clip to Valid Range (0-5)
final_preds = np.clip(final_preds, 0, 5)

submission = pd.DataFrame({
    'filename': df_test['filename'], 
    'label': final_preds
})

submission.to_csv('submission.csv', index=False)
print("submission.csv saved successfully!")
print(submission.head())
# Out:
# --- Phase 4: Feature Extraction (Test) ---
# Extracting features from Test Data...
# Processing Test:   0%|          | 0/197 [00:00<?, ?it/s]
# Applying Transforms to Test Data...
# Generating Submission...
# submission.csv saved successfully!
#     filename     label
# 0  audio_141  2.403084
# 1  audio_114  2.937991
# 2   audio_17  2.240748
# 3   audio_76  4.093138
# 4  audio_156  2.747084
